# %% [markdown]
# ### Problem: Largest palindrome product
#
# A palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99.
#
# Find the largest palindrome made from the product of two 3-digit numbers.

# %%
# first define the palindrome function
def palindrome(num1, num2):
    product = num1 * num2
    product_string = str(product)
    rev_product_string = str(product)[::-1] #returns string in reverse
    if product_string == rev_product_string:
        return True
    else:
        return False

# %%
# now make empty list to house all palindromes
palindrome_list = []
for i in range(100, 1000):
    for j in range(100, 1000):
        if palindrome(i, j) == True:
            palindrome_list.append(i*j)
            #print(str(i) + " times " + str(j) + " equals " + str(i*j))

print("There are " + str(len(palindrome_list)) + " possible palindromes made from the product of two 3-digit numbers.")
print("The largest of these palindrome products is " + str(max(palindrome_list)))
# Out:
# 101 times 101 equals 10201
# 101 times 111 equals 11211
# 101 times 121 equals 12221
# 101 times 131 equals 13231
# 101 times 141 equals 14241
# 101 times 151 equals 15251
# 101 times 161 equals 16261
# 101 times 171 equals 17271
# 101 times 181 equals 18281
# 101 times 191 equals 19291
# 101 times 202 equals 20402
# 101 times 212 equals 21412
# 101 times 222 equals 22422
# 101 times 232 equals 23432
# 101 times 242 equals 24442
# 101 times 252 equals 25452
# 101 times 262 equals 26462
# 101 times 272 equals 27472
# 101 times 282 equals 28482
# 101 times 292 equals 29492
# 101 times 303 equals 30603
# 101 times 313 equals 31613
# 101 times 323 equals 32623
# 101 times 333 equals 33633
# 101 times 343 equals 34643
# 101 times 353 equals 35653
# 101 times 363 equals 36663
# 101 times 373 equals 37673
# 101 times 383 equals 38683
# 101 times 393 equals 39693
# 101 times 404 equals 40804
# 101 times 414 equals 41814
# 101 times 424 equals 42824
# 101 times 434 equals 43834
# ...
